# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
cur.execute('''SELECT firstName, lastName, offices.city, offices.state 
FROM employees JOIN offices USING(officeCode) ORDER BY firstName''')
df = pd.DataFrame(cur.fetchall())
print('Number of results', len(df))
df
# Out:
# Number of results 23
#            0          1              2           3
# 0       Andy     Fixter         Sydney
# 1    Anthony        Bow  San Francisco          CA
# 2      Barry      Jones         London
# 3      Diane     Murphy  San Francisco          CA
# 4   Foon Yue      Tseng            NYC          NY
# 5     George     Vanauf            NYC          NY
# 6     Gerard     Bondur          Paris
# 7     Gerard  Hernandez          Paris
# 8       Jeff   Firrelli  San Francisco          CA
# 9      Julie   Firrelli         Boston          MA
# 10     Larry       Bott         London
# 11    Leslie   Jennings  San Francisco          CA
# 12    Leslie   Thompson  San Francisco          CA
# 13      Loui     Bondur          Paris
# 14      Mami      Nishi          Tokyo  Chiyoda-Ku
# 15    Martin     Gerard          Paris
# 16      Mary  Patterson  San Francisco          CA
# 17    Pamela   Castillo          Paris
# 18     Peter      Marsh         Sydney
# ...

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
cur.execute("""SELECT * FROM payments JOIN customers USING(customerNumber);""")
df = pd.DataFrame(cur.fetchall())
print('Number of results', len(df))
df.head()
# Out:
# Number of results 273
#     0         1           2         3                   4        5        6   \
# 0  103  HQ336336  2004-10-19   6066.78   Atelier graphique  Schmitt  Carine
# 1  103  JM555205  2003-06-05  14571.44   Atelier graphique  Schmitt  Carine
# 2  103  OM314933  2004-12-18   1676.14   Atelier graphique  Schmitt  Carine
# 3  112  BO864823  2004-12-17  14191.12  Signal Gift Stores     King     Jean
# 4  112   HQ55022  2003-06-06  32641.98  Signal Gift Stores     King     Jean
#
#            7                8  9          10  11     12      13    14  \
# 0  40.32.2555   54, rue Royale        Nantes      44000  France  1370
# 1  40.32.2555   54, rue Royale        Nantes      44000  France  1370
# 2  40.32.2555   54, rue Royale        Nantes      44000  France  1370
# 3  7025551838  8489 Strong St.     Las Vegas  NV  83030     USA  1166
# 4  7025551838  8489 Strong St.     Las Vegas  NV  83030     USA  1166
#
#          15
# 0  21000.00
# 1  21000.00
# 2  21000.00
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
# Your code here
cur.execute('''SELECT orderNumber, productCode, quantityOrdered, priceEach, orderLineNumber FROM orderDetails JOIN orders USING(orderNumber)''').fetchall()
# Out:
# [('10100', 'S18_1749', '30', '136.00', '3'),
#  ('10100', 'S18_2248', '50', '55.09', '2'),
#  ('10100', 'S18_4409', '22', '75.46', '4'),
#  ('10100', 'S24_3969', '49', '35.29', '1'),
#  ('10101', 'S18_2325', '25', '108.06', '4'),
#  ('10101', 'S18_2795', '26', '167.06', '1'),
#  ('10101', 'S24_1937', '45', '32.53', '3'),
#  ('10101', 'S24_2022', '46', '44.35', '2'),
#  ('10102', 'S18_1342', '39', '95.55', '2'),
#  ('10102', 'S18_1367', '41', '43.13', '1'),
#  ('10103', 'S10_1949', '26', '214.30', '11'),
#  ('10103', 'S10_4962', '42', '119.67', '4'),
#  ('10103', 'S12_1666', '27', '121.64', '8'),
#  ('10103', 'S18_1097', '35', '94.50', '10'),
#  ('10103', 'S18_2432', '22', '58.34', '2'),
#  ('10103', 'S18_2949', '27', '92.19', '12'),
#  ('10103', 'S18_2957', '35', '61.84', '14'),
#  ('10103', 'S18_3136', '25', '86.92', '13'),
#  ('10103', 'S18_3320', '46', '86.31', '16'),
#  ('10103', 'S18_4600', '36', '98.07', '5'),
#  ('10103', 'S18_4668', '41', '40.75', '9'),
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and allthe product information for each product in the order.

# %%
# Your code here
cur.execute("""SELECT * FROM orders JOIN payments ON (orders.orderDate = payments.paymentDate);""")
df = pd.DataFrame(cur.fetchall())
print('Number of results', len(df))
df.head()
# Out:
# Number of results 118
#       0           1           2           3        4   \
# 0  10116  2003-04-11  2003-04-19  2003-04-13  Shipped
# 1  10117  2003-04-16  2003-04-24  2003-04-17  Shipped
# 2  10123  2003-05-20  2003-05-29  2003-05-22  Shipped
# 3  10124  2003-05-21  2003-05-29  2003-05-25  Shipped
# 4  10125  2003-05-21  2003-05-27  2003-05-24  Shipped
#
#                                                   5    6    7         8   \
# 0                                                     381  124  CQ287967
# 1                                                     148  424  LM271923
# 2                                                     103  114   GG31455
# 3  Customer very concerned about the exact color ...  112  353  GT878649
# 4                                                     114  353  GT878649
#
#            9         10
# 0  2003-04-11  11044.30
# 1  2003-04-16  21665.98
# 2  2003-05-20  45864.03
# 3  2003-05-21  16700.47
# 4  2003-05-21  16700.47

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
